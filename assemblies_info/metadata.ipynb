# %%
# !wget https://ftp.ncbi.nlm.nih.gov/genomes/ASSEMBLY_REPORTS/assembly_summary_refseq.txt
# Out:
# --2023-08-30 20:49:29--  https://ftp.ncbi.nlm.nih.gov/genomes/ASSEMBLY_REPORTS/assembly_summary_genbank.txt
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 130.14.250.10, 130.14.250.11, 2607:f220:41e:250::10, ...
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|130.14.250.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 810271140 (773M) [text/plain]
# Saving to: ‘assembly_summary_genbank.txt’
#
# assembly_summary_ge 100%[===================>] 772.73M  46.9MB/s    in 18s
#
# 2023-08-30 20:49:48 (41.8 MB/s) - ‘assembly_summary_genbank.txt’ saved [810271140/810271140]

# %%
# !cat assembly_summary_refseq.txt |wc -l
# Out:
# 329246

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/assembly_summary_refseq.txt', sep='\t',skiprows=[0])
df
# Out:
# <ipython-input-47-1d97bfa30483>:1: DtypeWarning: Columns (34,35,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/assembly_summary_refseq.txt', sep='\t',skiprows=[0])
#        #assembly_accession   bioproject     biosample         wgs_master  \
# 0          GCF_018554485.1           na            na                 na
# 1          GCF_000006605.1  PRJNA224116  SAMEA3283089                 na
# 2          GCF_000006805.1  PRJNA224116  SAMN02604216                 na
# 3          GCF_000006905.1  PRJNA224116  SAMN02604005                 na
# 4          GCF_000007005.1  PRJNA224116  SAMN02603227                 na
# ...                    ...          ...           ...                ...
# 329239     GCF_030816095.1  PRJNA224116  SAMN34353115  JAUSXP000000000.1
# 329240     GCF_030812415.1  PRJNA224116  SAMN18243626  JAUSST000000000.1
# 329241     GCF_030814605.1  PRJNA224116  SAMN34353121  JAUSVI000000000.1
# ...

# %%
df.columns
# Out:
# Index(['#assembly_accession', 'bioproject', 'biosample', 'wgs_master',
#        'refseq_category', 'taxid', 'species_taxid', 'organism_name',
#        'infraspecific_name', 'isolate', 'version_status', 'assembly_level',
#        'release_type', 'genome_rep', 'seq_rel_date', 'asm_name',
#        'asm_submitter', 'gbrs_paired_asm', 'paired_asm_comp', 'ftp_path',
#        'excluded_from_refseq', 'relation_to_type_material',
#        'asm_not_live_date', 'assembly_type', 'group', 'genome_size',
#        'genome_size_ungapped', 'gc_percent', 'replicon_count',
#        'scaffold_count', 'contig_count', 'annotation_provider',
#        'annotation_name', 'annotation_date', 'total_gene_count',
#        'protein_coding_gene_count', 'non_coding_gene_count', 'pubmed_id'],
#       dtype='object')

# %%
metadata_df = pd.read_csv('/content/metadata.csv')

# %%
metadata_df
# Out:
#     RefSeq Assembly ID
# 0      GCF_000006765.1
# 1      GCF_000014625.1
# 2      GCF_000017205.1
# 3      GCF_000026645.1
# 4      GCF_000168335.1
# ..                 ...
# 496    GCF_016126955.1
# 497    GCF_016105505.1
# 498    GCF_016105665.1
# 499    GCF_016105885.1
# 500    GCF_001516365.2
#
# [501 rows x 1 columns]

# %%
joined_df = metadata_df.merge(df, how='left', left_on='RefSeq Assembly ID', right_on='#assembly_accession')

# %%
joined_df.to_csv('metadata_complete_v2.csv')

# %%
joined_df['RefSeq Assembly ID']
# Out:
# 0      GCF_000006765.1
# 1      GCF_000014625.1
# 2      GCF_000017205.1
# 3      GCF_000026645.1
# 4      GCF_000168335.1
#             ...
# 496    GCF_016126955.1
# 497    GCF_016105505.1
# 498    GCF_016105665.1
# 499    GCF_016105885.1
# 500    GCF_001516365.2
# Name: RefSeq Assembly ID, Length: 501, dtype: object

# %%
joined_df.columns
# Out:
# Index(['RefSeq Assembly ID', '#assembly_accession', 'bioproject', 'biosample',
#        'wgs_master', 'refseq_category', 'taxid', 'species_taxid',
#        'organism_name', 'infraspecific_name', 'isolate', 'version_status',
#        'assembly_level', 'release_type', 'genome_rep', 'seq_rel_date',
#        'asm_name', 'asm_submitter', 'gbrs_paired_asm', 'paired_asm_comp',
#        'ftp_path', 'excluded_from_refseq', 'relation_to_type_material',
#        'asm_not_live_date', 'assembly_type', 'group', 'genome_size',
#        'genome_size_ungapped', 'gc_percent', 'replicon_count',
#        'scaffold_count', 'contig_count', 'annotation_provider',
#        'annotation_name', 'annotation_date', 'total_gene_count',
#        'protein_coding_gene_count', 'non_coding_gene_count', 'pubmed_id'],
#       dtype='object')

# %%
joined_df
# Out:
#     RefSeq Assembly ID #assembly_accession   bioproject     biosample  \
# 0      GCF_000006765.1     GCF_000006765.1   PRJNA57945  SAMN02603714
# 1      GCF_000014625.1     GCF_000014625.1  PRJNA224116  SAMN02603591
# 2      GCF_000017205.1     GCF_000017205.1  PRJNA224116  SAMN02603435
# 3      GCF_000026645.1     GCF_000026645.1  PRJNA224116  SAMEA1705916
# 4      GCF_000168335.1     GCF_000168335.1  PRJNA224116  SAMN02471994
# ..                 ...                 ...          ...           ...
# 496    GCF_016126955.1     GCF_016126955.1  PRJNA224116  SAMN16357210
# 497    GCF_016105505.1     GCF_016105505.1  PRJNA224116  SAMN16673817
# 498    GCF_016105665.1     GCF_016105665.1  PRJNA224116  SAMN16673816
# 499    GCF_016105885.1     GCF_016105885.1  PRJNA224116  SAMN16673815
# 500    GCF_001516365.2     GCF_001516365.2  PRJNA224116  SAMN02894352
#
#          wgs_master   refseq_category     taxid  species_taxid  \
# ...

# %%
dfe = pd.DataFrame()
if  df is not None and not df.empty:
  print(1)
# Out:
# 1
